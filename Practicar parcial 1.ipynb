# %%
agenda = {}

def agregar_contacto():
    nombre = input("Ingrese el nombre: ")
    numero = input("Ingrese el número de teléfono: ")
    agenda[nombre] = numero
    print("Contacto agregado.")
    
# Ejemplo de uso:
while True:
    accion = input("¿Qué acción desea realizar? (Agregar / Ver / Eliminar / Salir): ")
    if accion.lower() == "agregar":
        agregar_contacto()
    elif accion.lower() == "ver":
        ver_contacto()
    elif accion.lower() == "eliminar":
        eliminar_contacto()
    elif accion.lower() == "salir":
        break
    else:
        print("Acción no reconocida.")
# Out:
# ¿Qué acción desea realizar? (Agregar / Ver / Eliminar / Salir): salir

# %%
agenda = {}

def agregar_contacto():
    nombre = input("Ingrese el nombre: ")
    numero = input("Ingrese el número de teléfono: ")
    agenda[nombre] = numero
    print("Contacto agregado.")

def ver_contacto():
    nombre = input("Ingrese el nombre: ")
    if nombre in agenda:
        print(nombre + ": " + agenda[nombre])
    else:
        print("Contacto no encontrado.")

def ver_agenda():
    for nombre, numero in agenda.items():
        print(nombre + ": " + numero)

def eliminar_contacto():
    nombre = input("Ingrese el nombre: ")
    if nombre in agenda:
        del agenda[nombre]
        print("Contacto eliminado.")
    else:
        print("Contacto no encontrado.")

# Ejemplo de uso:
while True:
    accion = input("¿Qué acción desea realizar? (Agregar / Ver / Eliminar / Salir): ")
    if accion.lower() == "agregar":
        agregar_contacto()
    elif accion.lower() == "ver":
        ver_contacto()
    elif accion.lower() == "eliminar":
        eliminar_contacto()
    elif accion.lower() == "salir":
        break
    else:
        print("Acción no reconocida.")
# Out:
# ¿Qué acción desea realizar? (Agregar ventas / Ver segun dia / Eliminar / Salir): salir

# %%
agenda = {}

def agregar_contacto():
    nombre = input("Ingrese el nombre: ")
    if nombre in agenda:
        print("El nombre ya se encuentra en la agenda. ¿Desea modificarlo? (S/N)")
        opcion = input().lower()
        if opcion == "s":
            numero = input("Ingrese el nuevo número de teléfono: ")
            agenda[nombre] = numero
            print("Contacto modificado.")
    else:
        numero = input("Ingrese el número de teléfono: ")
        agenda[nombre] = numero
        print("Contacto agregado.")

def ver_contacto():
    nombre = input("Ingrese el nombre: ")
    if nombre in agenda:
        print(nombre + ": " + agenda[nombre])
    else:
        print("Contacto no encontrado.")

def ver_agenda():
    for nombre, numero in agenda.items():
        print(nombre + ": " + numero)

def eliminar_contacto():
    nombre = input("Ingrese el nombre: ")
    if nombre in agenda:
        del agenda[nombre]
        print("Contacto eliminado.")
    else:
        print("Contacto no encontrado.")

# Ejemplo de uso:
while True:
    accion = input("¿Qué acción desea realizar? (Agregar / Ver / Eliminar / Salir): ")
    if accion.lower() == "agregar":
        agregar_contacto()
    elif accion.lower() == "ver":
        ver_contacto()
    elif accion.lower() == "eliminar":
        eliminar_contacto()
    elif accion.lower() == "salir":
        break
    else:
        print("Acción no reconocida.")
# Out:
# ¿Qué acción desea realizar? (Agregar / Ver / Eliminar / Salir): Salir

# %% [markdown]
# # Ejercicio 3  - Divisas

# %%
divisas = {'Euro':'€', 'Dollar':'$', 'Yen':'¥'}


divisa = input("Escribe una divisa: ")

if divisas.get(divisa):
    print(divisas.get(divisa))
else:
    print("Divisa no encontrada")
# Out:
# Escribe una divisa: Dollar
# $

# %% [markdown]
# # Ejercicio 4 - Info Persona

# %%
nombre = input("Ingrese su nombre: ")
edad= input("Ingrese su edad: ")
direccion = input("Ingrese su direccion: ")
numero = input("Ingrese su numero de celular: ")

datos_usuario = {'Nombre': nombre, 'Edad': edad, 'Direccion': direccion, 'Numero': numero}

print(f"{datos_usuario['Nombre']} tiene {datos_usuario['Edad']} años de edad, vive en {datos_usuario['Direccion']} y su número de telefono es {datos_usuario['Numero']}" )
# Out:
# Ingrese su nombre: Juan
# Ingrese su edad: 20
# Ingrese su direccion: Lorica
# Ingrese su numero de celular: 310
# Juan tiene 20 años de edad, vive en Lorica y su número de telefono es 310
